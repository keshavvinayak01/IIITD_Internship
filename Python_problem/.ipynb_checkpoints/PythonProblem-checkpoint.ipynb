# %%
import tweepy
import csv
import json
import pandas as pd
import requests
import re
import time

# %% [markdown]
# First part of the program where the data will be extracted and will be saved in json file

# %%
#loading twitter API credentials from the file which was saved
with open('twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']

# %%
# initialization of a list to hold all Tweets
alltweets = []

# %%
# Authorization and initialization
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
# We will get the tweets with multiple requests of 200 tweets each
new_tweets = api.user_timeline(screen_name="midasIIITD", count=200)
# Appending the json part of the data to list
for tweet in new_tweets:
    alltweets.append(tweet._json)

# %%
# save id of 1 less than the oldest tweet
oldest = alltweets[-1]["id"] - 1

# %%
# grabbing tweets till none are left
while len(new_tweets) > 0:  
    # all subsiquent requests use the max_id param to prevent duplicates
    new_tweets = api.user_timeline(screen_name = "midasIIITD",count=200, max_id=oldest)

    # save most recent tweets
    # Appending the json part of the data to list
    for tweet in new_tweets:
        alltweets.append(tweet._json)
    oldest = alltweets[-1]["id"] - 1

    print("...%s tweets downloaded so far" % (len(alltweets)))

print("Total tweets downloaded %s" % (len(alltweets)))
# Out:
# ...331 tweets downloaded so far
# ...331 tweets downloaded so far
# Total tweets downloaded 331

# %%
len_media = []

# %%
for i in range(len(alltweets)):
    try:
        len_media.append(len(alltweets[i]['entities']['media']))
    except:
        len_media.append(0)

# %%
# Creating a new JSON file and dumping the value into it
file = open('tweet.json', 'w')
json.dump(alltweets, file,indent = 4)

# %% [markdown]
# Second part of the program to parse the json file and display the output in tabular form

# %%
col_names = ["text", "Date and time", "number of favorites/likes", "number of retweets","Number of images"]

# %%
# function to get no. of retweets
def get_retweet(data):
    try:
        ans = data["retweeted_status"]["retweet_count"] 
    except KeyError:
        ans = data["retweet_count"] 
    return ans

# %%
# function to get no. of likes
def get_favorite(data):
    try:
        ans = data["retweeted_status"]["favorite_count"] 
    except KeyError:
        ans = data["favorite_count"] 
    return ans

# %%
# dataframe to show in tabular format
df = pd.DataFrame(columns=col_names)

# %%
alltweets[4]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Apr 05 16:08:37 +0000 2019',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1114198161562775553',
#     'indices': [117, 140],
#     'url': 'https://t.co/gZwyr7D2Sw'}],
#   'user_mentions': [{'id': 1021355762575073281,
#     'id_str': '1021355762575073281',
#     'indices': [71, 82],
#     'name': 'MIDAS IIITD',
#     'screen_name': 'midasIIITD'}]},
#  'favorite_count': 10,
#  'favorited': False,
#  'geo': None,
#  'id': 1114198161562775553,
#  'id_str': '1114198161562775553',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal.… https://t.co/gZwyr7D2Sw',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#       'expanded_url': 'http://midas.iiitd.edu.in/',
#       'indices': [0, 23],
#       'url': 'https://t.co/Uwg7oSM6mE'}]}},
#   'favourites_count': 142,
#   'follow_request_sent': False,
#   'followers_count': 255,
#   'following': True,
#   'friends_count': 42,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1021355762575073281,
#   'id_str': '1021355762575073281',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'New Delhi, India',
#   'name': 'MIDAS IIITD',
#   'notifications': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'midasIIITD',
#   'statuses_count': 331,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/Uwg7oSM6mE',
#   'utc_offset': None,
#   'verified': False}}

# %%
for i,tw in enumerate(all_tweets):
    text = re.sub(r"http\S+", "", tw["text"])
    dt = tw["created_at"].split()
    date = dt[2]+'-'+dt[1]+'-'+dt[-1]+"|"+dt[3]
    favorite = get_favorite(tw)
    retweet = get_retweet(tw)
#     images = get_photos(tw)
    df.loc[len(df)] = [text, date, favorite, retweet,len_media[i]]

# %%
df
# Out:
#                                                   text         Date and time  \
# 0    RT @kdnuggets: Top 8 #Free Must-Read #Books on...  06-Apr-2019|17:11:29
# 1    @nupur_baghel @PennDATS Congratulation @nupur_...  06-Apr-2019|16:43:27
# 2    We have emailed the task details to all candid...  05-Apr-2019|16:08:37
# 3    RT @rfpvjr: Our NAACL paper on polarization in...  05-Apr-2019|04:05:11
# 4    RT @kdnuggets: Effective Transfer Learning For...  05-Apr-2019|04:04:43
# 5    RT @stanfordnlp: What’s new in @Stanford CS224...  03-Apr-2019|18:31:53
# 6    RT @DeepMindAI: Today we're releasing a large-...  03-Apr-2019|17:04:32
# 7    RT @ylecun: Congratulations Jitendra Malik !\n...  03-Apr-2019|09:03:40
# 8    RT @IIITDelhi: Another chance to take admissio...  03-Apr-2019|07:46:02
# 9    Dear @midasIIITD internship candidates who hav...  02-Apr-2019|04:20:13
